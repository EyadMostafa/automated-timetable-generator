# %%
import pandas as pd

# %%
courses = pd.read_excel('./timetable-generator/tables/Courses.xlsx')
curriculum = pd.read_excel('./timetable-generator/tables/Curriculum.xlsx')
instructors = pd.read_excel('./timetable-generator/tables/Instructors.xlsx')
timeslots = pd.read_excel('./timetable-generator/tables/TimeSlots.xlsx')
sections = pd.read_excel('./timetable-generator/tables/Sections.xlsx')
rooms = pd.read_excel('./timetable-generator/tables/Rooms.xlsx')

# %%
courses
# Out:
#    course_id                           course_name                  type
# 0    LRA 401                     Japanese Language              Tutorial
# 1    LRA 104                 Music and Technoology               Lecture
# 2    CSC 111          Fundamentals of Programming            Lecture,Lab
# 3    PHY 113                           Physics (1)           Lecture,Lab
# 4    ECE 111                 Digital Logic Design   Lecture,Lab,Tutorial
# 5    MTH 111                       Mathematics (1)      Lecture,Tutorial
# 6    LRA 101                     Japanese Culture                Lecture
# 7    MTH 212            Probability and Statistics      Lecture,Tutorial
# 8    CSC 211                  Software Engineering           Lecture,Lab
# 9    ACM 215       Ordinary Differential Equations      Lecture,Tutorial
# 10   LRA 403                 Japanese Language (3)              Tutorial
# 11   CNC 111          Networks and Web Programming           Lecture,Lab
# ...

# %%
instructors
# Out:
#     instructor_id               name                role  \
# 0               1          Abo Rehab  Teaching Assistant
# 1               2         Adel Fathy              Doctor
# 2               3        Adel Shakal  Teaching Assistant
# 3               4   Ahmed Abdel-Malk              Doctor
# 4               5        Ahmed Allam           Professor
# 5               6        Ahmed Anter              Doctor
# 6               7        Ahmed Arafa              Doctor
# 7               8       Ahmed Bayumi              Doctor
# 8               9      Ahmed Zakaria           Professor
# 9              10       Ayan w Mayet  Teaching Assistant
# 10             11        Ayman Arafa              Doctor
# 11             12        Eman Refaat              Doctor
# 12             13      Fatma Elsayed  Teaching Assistant
# 13             14  Hamada El Safroot              Doctor
# 14             15             Hataba              Doctor
# ...

# %%
rooms
# Out:
#               room_id      type  capacity
# 0           B07 F1.01  Tutorial        15
# 1           B07 F1.02  Tutorial        15
# 2           B07 F1.04       Lab        15
# 3           B07 F1.20  Tutorial        15
# 4           B07 F1.21  Tutorial        15
# 5           B07 F1.22  Tutorial        15
# 6           B07 F1.23  Tutorial        15
# 7           B07 F1.24   Lecture        15
# 8             B07 G01   Lecture        45
# 9             B07 G12       Lab        15
# 10            B17.G17       Lab        45
# 11            B17-G01       Lab        30
# 12            B17-G16       Lab        15
# 13            B17-G16       Lab        15
# 14            B17-G22       Lab        30
# 15          B18 F1.08  Tutorial        15
# 16           B18 F1.1   Lecture        45
# 17          B18 F1.10   Lecture        45
# 18          B18 F1.12  Tutorial        15
# 19          B18 F1.13  Tutorial        15
# 20          B18 F1.19  Tutorial        15
# ...

# %%
sections
# Out:
#     section_id  year  student_count
# 0            1     1             15
# 1            2     1             15
# 2            3     1             15
# 3            4     1             15
# 4            5     1             15
# 5            6     1             15
# 6            7     1             15
# 7            8     1             15
# 8            9     1             15
# 9            1     2             15
# 10           2     2             15
# 11           3     2             15
# 12           4     2             15
# 13           5     2             15
# 14           6     2             15
# 15           7     2             15
# 16           8     2             15
# 17           9     2             15
# 18           1     3             15
# 19           2     3             15
# 20           3     3             15
# 21           4     3             15
# 22           5     3             15
# 23           6     3             15
# 24           7     3             15
# ...

# %%
timeslots
# Out:
#        time_slot_id        day start_time  end_time
# 0    sun_9:00_10:30     Sunday   09:00:00  10:30:00
# 1   sun_10:45_12:15     Sunday   10:45:00  12:15:00
# 2    sun_12:30_2:00     Sunday   12:30:00  02:00:00
# 3     sun_2:15_3:45     Sunday   02:15:00  03:45:00
# 4    mon_9:00_10:30     Monday   09:00:00  10:30:00
# 5   mon_10:45_12:15     Monday   10:45:00  12:15:00
# 6    mon_12:30_2:00     Monday   12:30:00  02:00:00
# 7     mon_2:15_3:45     Monday   02:15:00  03:45:00
# 8    tue_9:00_10:30    Tuesday   09:00:00  10:30:00
# 9   tue_10:45_12:15    Tuesday   10:45:00  12:15:00
# 10   tue_12:30_2:00    Tuesday   12:30:00  02:00:00
# 11    tue_2:15_3:45    Tuesday   02:15:00  03:45:00
# 12   wed_9:00_10:30  Wednesday   09:00:00  10:30:00
# 13  wed_10:45_12:15  Wednesday   10:45:00  12:15:00
# 14   wed_12:30_2:00  Wednesday   12:30:00  02:00:00
# 15    wed_2:15_3:45  Wednesday   02:15:00  03:45:00
# 16   thu_9:00_10:30   Thursday   09:00:00  10:30:00
# ...

# %%
curriculum
# Out:
#     year course_id
# 0      1   CSC 111
# 1      1   ECE 111
# 2      1   LRA 101
# 3      1   LRA 104
# 4      1   LRA 105
# 5      1   LRA 401
# 6      1   MTH 111
# 7      1   PHY 113
# 8      2   ACM 215
# 9      2   CNC 111
# 10     2   CSC 114
# 11     2   CSC 211
# 12     2   CSE 214
# 13     2   LRA 306
# 14     2   LRA 403
# 15     2   MTH 212
# 16     3   AID 311
# 17     3   AID 312
# 18     3   CNC 311
# 19     3   CNC 314
# 20     3   CSC 317
# 21     3   ECE 324
# 22     4  AID 321
# 23     4   AID 411
# 24     4   AID 413
# 25     4   AID 414
# 26     4   AID 417
# 27     4   AID 427
# 28     4   AID 428
